# %% [markdown]
# # 데이터분석 특화 라이브러리 : Pandas
#
# | **라이브러리 종류** | **Numpy** | **Pandas** |
# |:---:|:---|:---|
# | **지원가능 데이터** | `값으로만` 구성된 형태 | `값과 이름`이 부여된 테이블 형태 |
# | **데이터 사용형태** | N차원 `Array` | 1차원 `Series` + N차원 `DataFrame` |
# | **데이터 위치인덱싱** | `열인덱싱` | Series는 `행인덱싱` + DataFrame은 `행과 열인덱싱` |
# | **데이터분석 활용** | 수치계산 | 데이터분석 및 시각화 |
# | **성능** | 복잡한 작업에서도 `빠름` | 복잡한 작업에선 `느린편` |
# | **개발 언어** | `C언어` 기반 | `R언어` 기반 |
# | **머신러닝 및 딥러닝 적용** | 대부분 알고리즘의 `입력으로 사용` | 대부분 알고리즘의 `입력으로 사용하지 않음` |

# %% [markdown]
# # Series & DataFrame
#
# > - `엑셀에 익숙한 사용자`를 위해 제작 된 `테이블형태`의 데이터 구조
# > - 엑셀과 같은 `표 형태`의 데이터는 `데이터프레임(DataFrame)`, 데이터프레임의 `한 열`을 `시리즈(Series)` 라고 칭함
#
# ![image.png](attachment:image.png)
# (https://www.geeksforgeeks.org/creating-a-pandas-dataframe/)

# %% [markdown]
# ## Series

# %%
import pandas as pd 

ds = pd.Series([1, 2, 3, 4, 5])
ds
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ds.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Series 생성하되 index를 내가 원하는데로 변환하기
ds = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
ds
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# Series에서 c인덱스의 행값 출력
ds['c']
# Out:
# 3

# %%
ds>3
# Out:
# a    False
# b    False
# c    False
# d     True
# e     True
# dtype: bool

# %%
ds[ds > 3]
# Out:
# d    4
# e    5
# dtype: int64

# %%
ds*2
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
ds.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# dtype: bool

# %%
ds.notnull()
# Out:
# a    True
# b    True
# c    True
# d    True
# e    True
# dtype: bool

# %%
# 결측치 개수
ds.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## DataFrame

# %%
# 딕셔너리 데이터 생성
df = {'column1':[1,2,3,4,5],
      'another_column':['this', 'column', 'has', 'strings', 'inside!'],
      'float_column':[0.1, 0.5, 33, 48, 42.5555],
      'binary_column':[True, False, True, True, False]}
df
# Out:
# {'column1': [1, 2, 3, 4, 5],
#  'another_column': ['this', 'column', 'has', 'strings', 'inside!'],
#  'float_column': [0.1, 0.5, 33, 48, 42.5555],
#  'binary_column': [True, False, True, True, False]}

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#    column1 another_column  float_column  binary_column
# 0        1           this        0.1000           True
# 1        2         column        0.5000          False
# 2        3            has       33.0000           True
# 3        4        strings       48.0000           True
# 4        5        inside!       42.5555          False

# %%
# DataFrame의 새로운 열을 만들고 100으로 값을 채우기
df['column_test'] = 100
df
# Out:
#    column1 another_column  float_column  binary_column  column_test
# 0        1           this        0.1000           True          100
# 1        2         column        0.5000          False          100
# 2        3            has       33.0000           True          100
# 3        4        strings       48.0000           True          100
# 4        5        inside!       42.5555          False          100

# %%
# DataFrame의 새로운 열을 만들고 numpy.arange 사용해서 0~4로 값을 채우기
import numpy as np
df['seq_test'] = np.arange(5)
df
# Out:
#    column1 another_column  float_column  binary_column  column_test  seq_test
# 0        1           this        0.1000           True          100         0
# 1        2         column        0.5000          False          100         1
# 2        3            has       33.0000           True          100         2
# 3        4        strings       48.0000           True          100         3
# 4        5        inside!       42.5555          False          100         4

# %%
# DataFrame의 특정 열 삭제하기
del df['column_test']
df
# Out:
#    column1 another_column  float_column  binary_column  seq_test
# 0        1           this        0.1000           True         0
# 1        2         column        0.5000          False         1
# 2        3            has       33.0000           True         2
# 3        4        strings       48.0000           True         3
# 4        5        inside!       42.5555          False         4

# %%
df.T
# Out:
#                    0       1     2        3        4
# column1            1       2     3        4        5
# another_column  this  column   has  strings  inside!
# float_column     0.1     0.5  33.0     48.0  42.5555
# binary_column   True   False  True     True    False
# seq_test           0       1     2        3        4

# %%
# DataFrame의 열 이름 출력하기
df.columns
# Out:
# Index(['column1', 'another_column', 'float_column', 'binary_column',
#        'seq_test'],
#       dtype='object')

# %%
# DataFrame의 행 이름 출력하기
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# 값들만 출력
df.values
# Out:
# array([[1, 'this', 0.1, True, 0],
#        [2, 'column', 0.5, False, 1],
#        [3, 'has', 33.0, True, 2],
#        [4, 'strings', 48.0, True, 3],
#        [5, 'inside!', 42.5555, False, 4]], dtype=object)

# %% [markdown]
# # Data Loading

# %%
import pandas as pd

pd.read_csv()
pd.read_excel()
pd.read_sql()

# %%
# 아래 코드 실행 시 'Food_Agriculture_Organization_UN_Full.csv' 데이터 출력 가능
import pandas as pd
df_rel = pd.read_csv('FAOLEX_Agriculture.csv')
df_rel
# Out:
#             Record Id                                         Record URL  \
# 0      LEX-FAOC027670  http://www.fao.org/faolex/results/details/en/c...
# 1      LEX-FAOC095279  http://www.fao.org/faolex/results/details/en/c...
# 2      LEX-FAOC121539  http://www.fao.org/faolex/results/details/en/c...
# 3      LEX-FAOC139575  http://www.fao.org/faolex/results/details/en/c...
# 4      LEX-FAOC140890  http://www.fao.org/faolex/results/details/en/c...
# ...               ...                                                ...
# 95759  LEX-FAOC197684  http://www.fao.org/faolex/results/details/en/c...
# 95760  LEX-FAOC154195  http://www.fao.org/faolex/results/details/en/c...
# 95761  LEX-FAOC038493  http://www.fao.org/faolex/results/details/en/c...
# 95762  LEX-FAOC212828  http://www.fao.org/faolex/results/details/en/c...
# 95763  LEX-FAOC189494  http://www.fao.org/faolex/results/details/en/c...
#
#                                             Document URL  \
# 0      http://faolex.fao.org/docs/pdf/jap27670.pdf; h...
# 1            http://faolex.fao.org/docs/pdf/vie95279.pdf
# 2           http://faolex.fao.org/docs/pdf/ita121539.pdf
# 3           http://faolex.fao.org/docs/pdf/ecu139575.pdf
# 4           http://faolex.fao.org/docs/pdf/chn140890.pdf
# ...                                                  ...
# 95759       http://faolex.fao.org/docs/pdf/nsw197684.pdf
# 95760        http://faolex.fao.org/docs/pdf/uk154195.pdf
# 95761  http://faolex.fao.org/docs/pdf/uk38493original...
# 95762       http://faolex.fao.org/docs/pdf/ita212828.pdf
# 95763       http://faolex.fao.org/docs/pdf/uru189494.pdf
#
#                                                    Title  \
# 0      Act on Japanese Agricultural Standards (Act No...
# 1      Decision No. 2194/QD-TTg approving the Scheme ...
# 2      Regional Act No. 31 on agriculture, forests, f...
# 3      Acuerdo Nº 640 - Modifica el Acuerdo Nº 60, Es...
# 4      Measures of the Xinjiang Uygur Autonomous Regi...
# ...                                                  ...
# 95759  COVID-19 Legislation Amendment (Emergency Meas...
# 95760        Environment (Wales) Act 2016 (2016 anaw 3).
# 95761                 Environment Act 1995 (Chapter 25).
# 95762         National strategy for the circular economy
# 95763  Plan Ambiental Nacional para el Desarrollo Sos...
#
#                                           Original title  \
# 0                                         日本農林規格等に関する法律.
# 1                                                    NaN
# 2      Legge Regionale n. 31: Testo unico delle leggi...
# 3                                                    NaN
# 4                         新疆维吾尔自治区实施《中华人民共和国农民专业合作社法》办法。
# ...                                                  ...
# 95759                                                NaN
# 95760                                                NaN
# 95761                                                NaN
# 95762       Strategia nazionale per l’economia circolare
# 95763                                                NaN
#
#       Date of original text Last amended date  \
# 0                11-05-1950              2017
# 1                25-12-2009               NaN
# 2                05-12-2008               NaN
# 3                02-12-2010               NaN
# 4                29-03-2012               NaN
# ...                     ...               ...
# 95759            14-05-2020               NaN
# 95760            21-03-2016               NaN
# 95761            19-07-1995        01-05-2021
# 95762            30-09-2021               NaN
# 95763            20-12-2018               NaN
#
#                               Available website Language of document  \
# 0      http://www.japaneselawtranslation.go.jp/    English; Japanese
# 1                                           NaN              English
# 2                      www.regione.lombardia.it              Italian
# 3                     www.registroficial.gob.ec              Spanish
# 4                               cfc.agri.gov.cn              Chinese
# ...                                         ...                  ...
# 95759               www.legislation.nsw.gov.au/              English
# 95760                           www.opsi.gov.uk              English
# 95761                           www.opsi.gov.uk              English
# 95762                   https://www.mite.gov.it              Italian
# 95763                                       NaN              Spanish
#
#                                        Country/Territory  \
# 0                                                  Japan
# 1                                               Viet Nam
# 2                                                  Italy
# 3                                                Ecuador
# 4                                                  China
# ...                                                  ...
# 95759                                          Australia
# 95760  United Kingdom of Great Britain and Northern I...
# 95761  United Kingdom of Great Britain and Northern I...
# 95762                                              Italy
# 95763                                            Uruguay
#
#       Regional organizations Territorial subdivision Type of text Repealed  \
# 0                        NaN                     NaN  Legislation      NaN
# 1                        NaN                     NaN   Regulation      NaN
# 2                        NaN               Lombardia  Legislation      NaN
# 3                        NaN                     NaN   Regulation      NaN
# 4                        NaN                Xinjiang   Regulation      NaN
# ...                      ...                     ...          ...      ...
# 95759                    NaN         New South Wales  Legislation      NaN
# 95760                    NaN                   Wales  Legislation      NaN
# 95761                    NaN                     NaN  Legislation      NaN
# 95762                    NaN                     NaN       Policy      NaN
# 95763                    NaN                     NaN       Policy      NaN
#
#                                                 Abstract  \
# 0      The purpose of this Act is to enact appropriat...
# 1      This Decision approves the Scheme on the devel...
# 2      This Regional Act sets out the legislative fra...
# 3      El presente Acuerdo modifica el Estatuto Orgán...
# 4      These Measures, consisting of 38 Articles, are...
# ...                                                  ...
# 95759  The Act 2020 No. 5 to cope with the COVID-19 p...
# 95760  This Act makes provision with respect to a wid...
# 95761  The Act consists of 125 sections divided into ...
# 95762  The National strategy for the circular economy...
# 95763  El presente documento contiene el Plan Ambient...
#
#                                         Primary subjects  \
# 0      Agricultural & rural development; Food & nutri...
# 1                           Fisheries; Cultivated plants
# 2                       Agricultural & rural development
# 3                                 Fisheries; Land & soil
# 4      Agricultural & rural development; Private sect...
# ...                                                  ...
# 95759                   Health; Disaster risk management
# 95760             Environment; Wild species & ecosystems
# 95761                                        Environment
# 95762                                        Environment
# 95763                                        Environment
#
#                                                   Domain  \
# 0      Agriculture; Livestock; Food & nutrition; Fish...
# 1      Agriculture; Livestock; Fisheries; Forestry; C...
# 2      Agriculture; Livestock; Fisheries; Forestry; C...
# 3      Agriculture; Livestock; Fisheries; Forestry; L...
# 4      Agriculture; Livestock; Fisheries; Forestry; C...
# ...                                                  ...
# 95759  Energy; Environment; Fisheries; Land & soil; M...
# 95760  Air & atmosphere; Environment; Fisheries; Land...
# 95761  Air & atmosphere; Environment; Fisheries; Land...
# 95762  Air & atmosphere; Environment; Food & nutritio...
# 95763  Agriculture; Air & atmosphere; Energy; Environ...
#
#                                                 Keywords
# 0      basic legislation; certification; standards; i...
# 1      agricultural development; indigenous peoples; ...
# 2      agricultural development; subsidy/incentive; a...
# 3      institution; policy/planning; agricultural dev...
# 4      cooperative/producer organization; policy/plan...
# ...                                                  ...
# 95759  coronavirus disease (COVID-19); disasters; ins...
# 95760  framework law; institution; ecosystem conserva...
# 95761  framework law; basic legislation; institution;...
# 95762  circular economy; biodiversity; ecofriendly pr...
# 95763  sustainable use; biodiversity; agroecology; ma...
#
# [95764 rows x 18 columns]

# %% [markdown]
# # Data Display Options
#
#
# Pandas는 DataFrame을 기본적으로 `20개의 열과 60개의 행만 표시`(나머지 중간부분은 자름) <br>
# DataFrame `출력 제한을 변경`하는 옵션 존재
# - **pd.options.display.width:** `표시되는 디스플레이의 너비`로 지정 너비를 벗어나는 길이의 값이면 줄 바꿈하여 표시
# - **pd.options.display.max_rows:** `표시되는 최대 행 수`
# - **pd.options.display.max_columns:** `표시되는 최대 열 수`

# %%
# 화면에 표시되는 출력 결과물을 갯수를 설정 가능
pd.options.display.max_rows = 5
pd.options.display.max_columns = 10

# %%
df_rel
# Out:
#             Record Id                                         Record URL  \
# 0      LEX-FAOC027670  http://www.fao.org/faolex/results/details/en/c...
# ...               ...                                                ...
# 95763  LEX-FAOC189494  http://www.fao.org/faolex/results/details/en/c...
#
#                                             Document URL  \
# 0      http://faolex.fao.org/docs/pdf/jap27670.pdf; h...
# ...                                                  ...
# 95763       http://faolex.fao.org/docs/pdf/uru189494.pdf
#
#                                                    Title  Original title  ...  \
# 0      Act on Japanese Agricultural Standards (Act No...  日本農林規格等に関する法律.  ...
# ...                                                  ...             ...  ...
# 95763  Plan Ambiental Nacional para el Desarrollo Sos...             NaN  ...
#
#       Repealed                                           Abstract  \
# 0          NaN  The purpose of this Act is to enact appropriat...
# ...        ...                                                ...
# 95763      NaN  El presente documento contiene el Plan Ambient...
#
#                                         Primary subjects  \
# 0      Agricultural & rural development; Food & nutri...
# ...                                                  ...
# 95763                                        Environment
#
#                                                   Domain  \
# 0      Agriculture; Livestock; Food & nutrition; Fish...
# ...                                                  ...
# 95763  Agriculture; Air & atmosphere; Energy; Environ...
#
#                                                 Keywords
# 0      basic legislation; certification; standards; i...
# ...                                                  ...
# 95763  sustainable use; biodiversity; agroecology; ma...
#
# [95764 rows x 18 columns]

# %% [markdown]
# # Data Descriptive Statistics
#
#
# > - 데이터를 불러온 후, `가장 처음하는 작업`으로 `데이터 구조, 형태, 특성을 빠르게 확인`하는게 목적
# > - `DataFrame.describe()` 함수는 적용되는 모든 변수 또는 그룹의 `통계를 빠르게 표시`하는 유용한 요약 도구
#
# | **Function** | **Description**                         |
# |:--------:|:------------------------------------|
# | **count**    | Number of non-null observations     |
# | **sum**      | Sum of values                       |
# | **mean**     | Mean of values                      |
# | **mad**      | Mean absolute deviation             |
# | **median**   | Arithmetic median of values         |
# | **min**      | Minimum                             |
# | **max**      | Maximum                             |
# | **mode**     | Mode                                |
# | **abs**      | Absolute Value                      |
# | **prod**     | Product of values                   |
# | **std**      | Unbiased standard deviation         |
# | **var**      | Unbiased variance                   |
# | **sem**      | Unbiased standard error of the mean |
# | **skew**     | Unbiased skewness (3rd moment)      |
# | **kurt**     | Unbiased kurtosis (4th moment)      |
# | **quantile** | Sample quantile (value at %)        |
# | **cumsum**   | Cumulative sum                      |
# | **cumprod**  | Cumulative product                  |
# | **cummax**   | Cumulative maximum                  |
# | **cummin**   | Cumulative minimum                  |
#
# ---
#
# | **Usage** 	| **Description** 	|
# |:---:|:---|
# | **df.head()** 	| 데이터의 상단 부분만 출력 	|
# | **df.tail()** 	| 데이터의 하단 부분만 출력 	|
# | **df.shape()** 	| 데이터의 행과 열의 개수 출력 	|
# | **df.describe()** 	| 데이터의 기초적인 통계정보 출력 	|
# | **df.columns** 	| 데이터의 전체 컬럼(열이름) 출력 	|
# | **df.index** 	| 데이터의 전체 인덱스(행이름) 출력 	|
# | **df.values** 	| 데이터프레임의 내부값들을 Array로 출력 	|

# %%
# 인덱스로 데이터 확인
# 해당 인덱스번호에 해당하는 데이터 추출(복수 추출 가능)
df_rel.take([10, 20, 25])
# Out:
#          Record Id                                         Record URL  \
# 10  LEX-FAOC150614  http://www.fao.org/faolex/results/details/en/c...
# ..             ...                                                ...
# 25  LEX-FAOC180464  http://www.fao.org/faolex/results/details/en/c...
#
#                                          Document URL  \
# 10       http://faolex.fao.org/docs/pdf/col150614.pdf
# ..                                                ...
# 25  http://faolex.fao.org/docs/pdf/chn180464.pdf; ...
#
#                                                 Title Original title  ...  \
# 10  Decreto Nº 1449 - Modifica parcialmente el Dec...            NaN  ...
# ..                                                ...            ...  ...
# 25                 Organic Agriculture Promotion Act.       有機農業促進法.  ...
#
#    Repealed                                           Abstract  \
# 10      NaN  El presente Decreto modifica el Decreto Único ...
# ..      ...                                                ...
# 25      NaN  The Act has been enacted for maintaining water...
#
#                                      Primary subjects  \
# 10        Agricultural & rural development; Fisheries
# ..                                                ...
# 25  Agricultural & rural development; Cultivated p...
#
#                                                Domain  \
# 10  Agriculture; Livestock; Fisheries; Forestry; C...
# ..                                                ...
# 25  Agriculture; Livestock; Food & nutrition; Fish...
#
#                                              Keywords
# 10  institution; legal proceedings/administrative ...
# ..                                                ...
# 25  basic legislation; ecological production/organ...
#
# [3 rows x 18 columns]

# %%
# 컬럼명 확인
df_rel.columns
# Out:
# Index(['Record Id', 'Record URL', 'Document URL', 'Title', 'Original title',
#        'Date of original text', 'Last amended date', 'Available website',
#        'Language of document', 'Country/Territory', 'Regional organizations',
#        'Territorial subdivision', 'Type of text', 'Repealed', 'Abstract',
#        'Primary subjects', 'Domain', 'Keywords'],
#       dtype='object')

# %%
# 데이터 값의 형태 확인
# object == str
df_rel.dtypes
# Out:
# Record Id    object
#               ...
# Keywords     object
# Length: 18, dtype: object

# %%
# 데이터의 전반적인 정보를 확인
df_rel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95764 entries, 0 to 95763
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record Id                95764 non-null  object
#  1   Record URL               95764 non-null  object
#  2   Document URL             95759 non-null  object
#  3   Title                    95764 non-null  object
#  4   Original title           27800 non-null  object
#  5   Date of original text    95747 non-null  object
#  6   Last amended date        11954 non-null  object
#  7   Available website        70757 non-null  object
#  8   Language of document     95750 non-null  object
#  9   Country/Territory        95022 non-null  object
#  10  Regional organizations   943 non-null    object
#  11  Territorial subdivision  13035 non-null  object
#  12  Type of text             95764 non-null  object
#  13  Repealed                 12647 non-null  object
#  14  Abstract                 95679 non-null  object
#  15  Primary subjects         95764 non-null  object
#  16  Domain                   95764 non-null  object
#  17  Keywords                 95763 non-null  object
# dtypes: object(18)
# memory usage: 13.2+ MB

# %%
# 특정 컬럼의 중복되지 않은 독립된 값 출력
df_rel['Language of document'].unique()
# Out:
# array(['English; Japanese', 'English', 'Italian', 'Spanish', 'Chinese',
#        'Portuguese', 'French', 'English; Chinese', 'Chinese; English',
#        'Arabic', 'Vietnamese', 'Vietnamese; English', 'Croatian',
#        'Turkish', 'Swedish', 'Hungarian', 'french', 'Russian',
#        'Bosnian; English', 'Ukrainian', 'French; English',
#        'English; Khmer', 'Danish', 'Arabic; English', 'English; German',
#        'Serbian', 'German', 'Turkish; English', 'Georgian',
#        'Norwegian; English', 'Dutch; English', 'English; Georgian',
#        'English; Estonian', 'Indonesian', 'Montenegrin', 'Czech',
#        'Turkish; English; Macedonian', 'English; Spanish; Turkish',
#        'Turkish; English; French', 'Turkish; English; Greek',
#        'Turkish; English; Estonian', 'Turkish; English; Arabic',
#        'English; Montenegrin; Turkish', 'Turkish; English; Khmer',
#        'Turkish; Serbian; English', 'Albanian', 'Greek',
#        'English; Latvian', 'Norwegian', 'English; Burmese',
#        'Russian; English', 'Bosnian', 'English; Swedish', 'English; Lao',
#        'Macedonian; English', 'spanish', 'English; French', 'Azerbaijani',
#        'Portuguese; English', 'Dutch', 'Slovak', 'Japanese', 'Latvian',
#        'Polish', 'Macedonian', 'Uzbek', 'Turkish; English; Russian',
#        'Turkish; English; Spanish', 'Bulgarian', 'Catalan', 'Farsi',
#        'Bengali', 'Spanish; English', 'Swedish; English',
#        'English; French; Portuguese', 'Romanian', 'English; Portuguese',
#        'Slovenian', 'Japanese; English', 'Armenian', 'Icelandic',
#        'English; Macedonian', 'English; Russian',
#        'English; Russian; Ukrainian', 'English; Bulgarian',
#        'English; Korean', 'Hebrew', 'English; Turkish', 'Mongolian',
#        'German; Russian', 'Somali', 'English; Spanish',
#        'Indonesian; English', 'French; English; German; Italian', 'Lao',
#        'Lithuanian', 'French; Dutch; German', 'French; Dutch',
#        'Bulgarian; English', 'portuguese', 'German; English',
#        'English; Thai', 'Nepali', 'English; Hebrew', 'French; Italian',
#        'English; Hindi', 'Spanish; Catalan', 'English; Greek',
#        'Portuguese; French', 'English; Indonesian', 'Italian; English',
#        'HEBREW', 'Russian; Lithuanian', 'Turkish; Arabic; English',
#        'Danish; English', 'English; Slovenian', nan, 'German; Slovak',
#        'Khmer', 'English; Norwegian', 'Portuguese; Chinese',
#        'English; Vietnamese', 'English; Icelandic', 'Slovenian; English',
#        'English; Czech', 'Nepali; English', 'Dzongkha; English',
#        'Portuguese; English; Spanish; French',
#        'English; Mongolian; Russian', 'italian', 'English; Finnish',
#        'Russian; Romanian', 'German; Serbian', 'Chinese; Portuguese',
#        'Finnish', 'English; Danish', 'English; Mongolian',
#        'Serbian; English', 'Croatian; English', 'English; Slovak',
#        'Burmese', 'UZBEK', 'Estonian', 'Thai', 'Burmese; English',
#        'Turkish; English; Azerbaijani', 'Turkish; French; English',
#        'Turkish; French', 'Turkish; English; Montenegrin',
#        'Somali; English', 'English; Arabic', 'English; Armenian',
#        'Turkish; English; Romanian', 'Armenian; English', 'CROATIAN',
#        'Italian; French', 'Greek; English', 'German; Bulgarian',
#        'German; Romanian', 'English; Malay', 'Dutch; French',
#        'French; Italian; German', 'Bengali; English', 'English; Amharic',
#        'Turkish; Russian; English', 'English; French; Japanese; Russian',
#        'Portuguese; Spanish', 'Montenegrin; English', 'Thai; English',
#        'Catalán', 'Norwegian; Finnish', 'Sinhala; English', 'ENGLISH',
#        'English; Dhivehi',
#        'English; Danish; German; Greek; French; Italian; Dutch',
#        'Turkish; English; Ukrainian', 'Malay', 'Arabic; English; French',
#        'English; Lithuanian', 'English; Montenegrin',
#        'Turkish; Arabic; French', 'Croatian; English; Turkish',
#        'Arabic; English; Turkish', 'English; Serbian; Turkish',
#        'Greek; Spanish', 'Spanish; French', 'greek', 'Ukrainian; English',
#        'Greek; French; English', 'English; Dzongkha',
#        'French; German; Italian', 'Arabic; French', 'SPANISH',
#        'English; Serbian', 'German; Hungarian', 'ِArabic', 'english',
#        'English; french', 'Turkish; Azerbaijani; English',
#        'Finnish; English', 'English; Spanish; French',
#        'English; Azerbaijani', 'SLovenian', 'Turkish; English; German',
#        'English; English', 'French; German', 'French; English; Arabic',
#        'Turkish; English; Chinese', 'Turkish; English; Serbian',
#        'English; Latvian; Russian', 'Tajik', 'English; Maori',
#        'English; Russian; Azerbaijani', '\xa0Slovak',
#        'Russian; English; Tajik', 'ENglish', 'Farsi; English',
#        'English; Georgian; Azerbaijani; Armenian', 'Georgian; English',
#        'English; Hungarian', 'English; khmer', 'Georgian; Russian',
#        'Azerbaijani; English', 'English; Farsi', 'Slovak; English',
#        'English; Polish', 'English; Nepali', 'arabic',
#        'Turkish; English; Georgian', 'English; Dutch', 'German; Spanish',
#        'German; Arabic', 'English; Romanian', 'French; English; German',
#        'English; Russian; Romanian', 'russian', 'Hindi; English',
#        'English; Italian'], dtype=object)

# %%
df_rel['Language of document'].isin(['English']).sum()
# Out:
# 26273

# %%
# 특정 컬럼의 값들이 무엇이 있고 몇개씩인지 한꺼번에 출력 (빈도확인)
df_rel['Language of document'].value_counts()
# Out:
# English                          26273
# Spanish                          23769
#                                  ...
# English; Montenegrin; Turkish        1
# English; Italian                     1
# Name: Language of document, Length: 237, dtype: int64

# %%
# 선택한 Series의 기초통계 출력
df_rel.describe()
# Out:
#              Record Id                                         Record URL  \
# count            95764                                              95764
# unique           95762                                              95762
# top     LEX-FAOC053010  http://www.fao.org/faolex/results/details/en/c...
# freq                 2                                                  2
#
#                                              Document URL  \
# count                                               95759
# unique                                              95758
# top     http://faolex.fao.org/docs/pdf/tur172708.pdf; ...
# freq                                                    2
#
#                                                     Title  \
# count                                               95764
# unique                                              93637
# top     Ordinance amending the Plant Protection Ordina...
# freq                                                   29
#
#                                 Original title  ... Repealed  \
# count                                    27800  ...    12647
# unique                                   26057  ...        1
# top     Änderung der Pflanzenschutzverordnung.  ...        Y
# freq                                        26  ...    12647
#
#                                                  Abstract Primary subjects  \
# count                                               95679            95764
# unique                                              94859              613
# top     The Governor decrees that Regional Forest plan...        Fisheries
# freq                                                   24            20328
#
#            Domain     Keywords
# count       95764        95763
# unique       2322        69478
# top     Fisheries  institution
# freq        18559          266
#
# [4 rows x 18 columns]

# %%
# 문자도 포함한 DataFrame 기초통계 출력
# 문자 컬럼에선 다른 통계정보가 출력
df_rel.describe(include='all')
# Out:
#              Record Id                                         Record URL  \
# count            95764                                              95764
# unique           95762                                              95762
# top     LEX-FAOC053010  http://www.fao.org/faolex/results/details/en/c...
# freq                 2                                                  2
#
#                                              Document URL  \
# count                                               95759
# unique                                              95758
# top     http://faolex.fao.org/docs/pdf/tur172708.pdf; ...
# freq                                                    2
#
#                                                     Title  \
# count                                               95764
# unique                                              93637
# top     Ordinance amending the Plant Protection Ordina...
# freq                                                   29
#
#                                 Original title  ... Repealed  \
# count                                    27800  ...    12647
# unique                                   26057  ...        1
# top     Änderung der Pflanzenschutzverordnung.  ...        Y
# freq                                        26  ...    12647
#
#                                                  Abstract Primary subjects  \
# count                                               95679            95764
# unique                                              94859              613
# top     The Governor decrees that Regional Forest plan...        Fisheries
# freq                                                   24            20328
#
#            Domain     Keywords
# count       95764        95763
# unique       2322        69478
# top     Fisheries  institution
# freq        18559          266
#
# [4 rows x 18 columns]

# %% [markdown]
# # Selection and Indexing

# %% [markdown]
# ## copy, slicing, indexing

# %%
# 데이터 복사 저장
df_series = df_rel['Language of document'].copy()
df_series
# Out:
# 0        English; Japanese
# 1                  English
#                ...
# 95762              Italian
# 95763              Spanish
# Name: Language of document, Length: 95764, dtype: object

# %%
# 1, 2, 3번 인덱스에 해당되는 샘플 출력
df_series[[1, 2, 3]]
# Out:
# 1    English
# 2    Italian
# 3    Spanish
# Name: Language of document, dtype: object

# %%
# 인덱스의 비교 연산 가능
df_series.index == 'English'
# Out:
# array([False, False, False, ..., False, False, False])

# %%
# 1이상 5미만의 인덱스 값만 추출
df_series[1:5]
# Out:
# 1    English
# 2    Italian
# 3    Spanish
# 4    Chinese
# Name: Language of document, dtype: object

# %%
# 1이상 3미만의 인덱스 값 변환
df_series[1:3] = 'Test'
df_series
# Out:
# 0        English; Japanese
# 1                     Test
#                ...
# 95762              Italian
# 95763              Spanish
# Name: Language of document, Length: 95764, dtype: object

# %% [markdown]
# ## iloc & loc
#
# ![image.png](attachment:image.png)
